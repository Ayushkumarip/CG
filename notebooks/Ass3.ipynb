# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushkumarip/CG/blob/main/notebooks/Ass3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from scipy import stats
import seaborn as sns

# Load dataset
iris = datasets.load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Select two variables
x = df['sepal length (cm)']
y = df['petal length (cm)']

# %%
plt.scatter(x, y)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Scatter Plot")
plt.show()

# %%
plt.hist(x, bins=20)
plt.title("Histogram - Sepal Length")
plt.show()

# %%
stats.probplot(x, dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.show()

# %%
sns.boxplot(x=x)
plt.title("Boxplot")
plt.show()

# %%
stat, p = stats.shapiro(x)

print("Shapiro-Wilk Test:")
print("Statistic =", stat)
print("p-value =", p)
# Out:
# Shapiro-Wilk Test:
# Statistic = 0.9760902723490532
# p-value = 0.010181161454691156

# %%
skewness = stats.skew(x)
print("Skewness =", skewness)
# Out:
# Skewness = 0.3117530585022963

# %%
corr, pval = stats.spearmanr(x, y)

print("Spearman Correlation =", corr)
print("p-value =", pval)
# Out:
# Spearman Correlation = 0.881898126434986
# p-value = 3.4430872780470036e-50
