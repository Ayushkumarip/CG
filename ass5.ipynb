# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushkumarip/CG/blob/main/ass5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk-headless -qq
# Out:
# Selecting previously unselected package libxtst6:amd64.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../openjdk-8-jre-headless_8u482-ga~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u482-ga~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../openjdk-8-jdk-headless_8u482-ga~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u482-ga~us1-0ubuntu1~22.04) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up openjdk-8-jre-headless:amd64 (8u482-ga~us1-0ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# ...

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

# %%
# !wget -q https://archive.apache.org/dist/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz

# %%
os.environ["HADOOP_HOME"] = "/content/hadoop-3.3.6"
os.environ["PATH"] += ":/content/hadoop-3.3.6/bin"

# %%
# !hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/hadoop-3.3.6/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# !mkdir -p /content/hadoop_tmp

# %%
# %%bash
# cat > /content/hadoop-3.3.6/etc/hadoop/core-site.xml <<EOF
# <configuration>
# <property>
# <name>fs.defaultFS</name>
# <value>file:///</value>
# </property>
# </configuration>
# EOF

# %%
# !wget -q https://archive.apache.org/dist/hive/hive-3.1.3/apache-hive-3.1.3-bin.tar.gz
# !tar -xzf apache-hive-3.1.3-bin.tar.gz

# %%
os.environ["HIVE_HOME"] = "/content/apache-hive-3.1.3-bin"
os.environ["PATH"] += ":/content/apache-hive-3.1.3-bin/bin"

# %%
# !schematool -dbType derby -initSchema
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Metastore connection URL:	 jdbc:derby:;databaseName=metastore_db;create=true
# Metastore Connection Driver :	 org.apache.derby.jdbc.EmbeddedDriver
# Metastore connection User:	 APP
# Starting metastore schema initialization to 3.1.0
# Initialization script hive-schema-3.1.0.derby.sql
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# !hive -e "SHOW DATABASES;"
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Hive Session ID = 714c9657-c20a-4d68-b65b-6c4ddba9bef6
#
# Logging initialized using configuration in jar:file:/content/apache-hive-3.1.3-bin/lib/hive-common-3.1.3.jar!/hive-log4j2.properties Async: true
# Hive Session ID = 808e781a-c385-4676-83c1-acecf441636d
# OK
# default
# Time taken: 2.409 seconds, Fetched: 1 row(s)

# %%
# !wget -q https://archive.apache.org/dist/pig/pig-0.17.0/pig-0.17.0.tar.gz
# !tar -xzf pig-0.17.0.tar.gz

# %%
os.environ["PIG_HOME"] = "/content/pig-0.17.0"
os.environ["PATH"] += ":/content/pig-0.17.0/bin"

# %%
# !echo -e "Ayush,21\nRahul,22\nRiya,20" > data.csv

# %%
# !pig -x local -e "A = LOAD 'data.csv' USING PigStorage(',') AS (name:chararray, age:int); B = FILTER A BY age > 20; DUMP B;"
# Out:
# 2026-05-03 20:37:13,555 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2026-05-03 20:37:13,556 INFO pig.ExecTypeProvider: Picked LOCAL as the ExecType
# 2026-05-03 20:37:13,655 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2026-05-03 20:37:13,655 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1777840633651.log
# 2026-05-03 20:37:13,745 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2026-05-03 20:37:13,748 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: file:///
# 2026-05-03 20:37:13,923 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - io.bytes.per.checksum is deprecated. Instead, use dfs.bytes-per-checksum
# ...

# %%
# !pig version
# Out:
# 2026-05-03 20:35:27,742 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2026-05-03 20:35:27,744 INFO pig.ExecTypeProvider: Trying ExecType : MAPREDUCE
# 2026-05-03 20:35:27,745 INFO pig.ExecTypeProvider: Picked MAPREDUCE as the ExecType
# 2026-05-03 20:35:27,913 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2026-05-03 20:35:27,913 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1777840527902.log
# 2026-05-03 20:35:28,379 [main] ERROR org.apache.pig.Main - ERROR 2997: Encountered IOException. File version does not exist
# Details at logfile: /content/pig_1777840527902.log
# 2026-05-03 20:35:28,410 [main] INFO  org.apache.pig.Main - Pig script completed in 759 milliseconds (759 ms)
